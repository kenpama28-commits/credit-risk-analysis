# %%
import pandas as pd
import numpy as np
import os
import subprocess

print("✅ Pandas:", pd.__version__)
print("✅ NumPy:", np.__version__)
print("✅ Directorio de trabajo:", os.getcwd())
# Out:
# ✅ Pandas: 2.2.2
# ✅ NumPy: 1.26.4
# ✅ Directorio de trabajo: c:\Users\kenpa\OneDrive\Desktop\FORMACION\credit-risk-analysis

# %%
import os
import subprocess

os.makedirs("../data/raw", exist_ok=True)

result = subprocess.run([
    "kaggle", "competitions", "download",
    "-c", "GiveMeSomeCredit",
    "-p", "../data/raw"
], capture_output=True, text=True)

print("STDOUT:\n", result.stdout)
print("STDERR:\n", result.stderr)
print("RETURN CODE:", result.returncode)
# Out:
# STDOUT:
# ...
#
#
# STDERR:
#
#   0%|          | 0.00/5.16M [00:00<?, ?B/s]
#  19%|â–ˆâ–‰        | 1.00M/5.16M [00:00<00:01, 2.95MB/s]
#  78%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š  | 4.00M/5.16M [00:00<00:00, 10.8MB/s]
# 100%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ| 5.16M/5.16M [00:00<00:00, 10.8MB/s]
#
# RETURN CODE: 0

# %%
# Descarga el dataset directamente desde Kaggle
os.makedirs("../data/raw", exist_ok=True)

subprocess.run([
    "kaggle", "competitions", "download",
    "-c", "GiveMeSomeCredit",
    "-p", "C:\\Users\\kenpa\\OneDrive\\Desktop\\FORMACION\\credit-risk-analysis\\data\\raw"
], check=True)

print("✅ Dataset descargado correctamente")
# Out:
# ✅ Dataset descargado correctamente

# %%
import zipfile

zip_path = "C:\\Users\\kenpa\\OneDrive\\Desktop\\FORMACION\\credit-risk-analysis\\data\\raw\\GiveMeSomeCredit.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("C:\\Users\\kenpa\\OneDrive\\Desktop\\FORMACION\\credit-risk-analysis\\data\\raw\\")

print("✅ Archivos extraídos:")
for f in os.listdir("C:\\Users\\kenpa\\OneDrive\\Desktop\\FORMACION\\credit-risk-analysis\\data\\raw\\"):
    print("  ", f)
# Out:
# ✅ Archivos extraídos:
#    cs-test.csv
#    cs-training.csv
#    Data Dictionary.xls
#    GiveMeSomeCredit.zip
#    sampleEntry.csv

# %%
df = pd.read_csv("C:\\Users\\kenpa\\OneDrive\\Desktop\\FORMACION\\credit-risk-analysis\\data\\raw\\cs-training.csv", index_col=0)

print(f"📊 Dimensiones del dataset: {df.shape[0]:,} filas × {df.shape[1]} columnas")
print(f"\n📋 Columnas disponibles:\n")

for col in df.columns:
    print(f"  · {col}")
# Out:
# 📊 Dimensiones del dataset: 150,000 filas × 11 columnas
#
# 📋 Columnas disponibles:
#
#   · SeriousDlqin2yrs
#   · RevolvingUtilizationOfUnsecuredLines
#   · age
#   · NumberOfTime30-59DaysPastDueNotWorse
#   · DebtRatio
#   · MonthlyIncome
#   · NumberOfOpenCreditLinesAndLoans
#   · NumberOfTimes90DaysLate
#   · NumberRealEstateLoansOrLines
#   · NumberOfTime60-89DaysPastDueNotWorse
#   · NumberOfDependents

# %%
print("=== VISTA PREVIA ===")
display(df.head(10))

print("\n=== TIPOS DE DATOS ===")
display(df.dtypes.to_frame(name="Tipos de datos"))

print("\n=== ESTADÍSTICAS BÁSICAS ===")
display(df.describe().round(2))
# Out:
# === VISTA PREVIA ===
#     SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                  1                              0.766127   45
# 2                  0                              0.957151   40
# 3                  0                              0.658180   38
# 4                  0                              0.233810   30
# 5                  0                              0.907239   49
# 6                  0                              0.213179   74
# 7                  0                              0.305682   57
# 8                  0                              0.754464   39
# 9                  0                              0.116951   27
# 10                 0                              0.189169   57
#
#     NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 1                                      2     0.802982         9120.0
# 2                                      0     0.121876         2600.0
# ...

# %%
# Documentamos el estado raw del dataset (buena práctica profesional)
reporte_inicial = {
    "filas": df.shape[0],
    "columnas": df.shape[1],
    "nulos_totales": df.isnull().sum().sum(),
    "duplicados": df.duplicated().sum(),
    "variable_objetivo": "SeriousDlqin2yrs",
    "tasa_morosidad_inicial": f"{df['SeriousDlqin2yrs'].mean()*100:.2f}%"
}

for k, v in reporte_inicial.items():
    print(f"  {k}: {v}")
# Out:
#   filas: 150000
#   columnas: 11
#   nulos_totales: 33655
#   duplicados: 609
#   variable_objetivo: SeriousDlqin2yrs
#   tasa_morosidad_inicial: 6.68%

# %%
df["age"].value_counts().sort_index()
# Out:
# age
# 0        1
# 21     183
# 22     434
# 23     641
# 24     816
#       ...
# 102      3
# 103      3
# 105      1
# 107      1
# 109      2
# Name: count, Length: 86, dtype: int64
